# %%
import torch

# %%
dinov2_vitb14_reg = torch.hub.load('facebookresearch/dinov2', 'dinov2_vitb14_reg')
backbone = dinov2_vitb14_reg
print(backbone)
# Out:
# Using cache found in /root/.cache/torch/hub/facebookresearch_dinov2_main
# /root/.cache/torch/hub/facebookresearch_dinov2_main/dinov2/layers/swiglu_ffn.py:51: UserWarning: xFormers is not available (SwiGLU)
#   warnings.warn("xFormers is not available (SwiGLU)")
# /root/.cache/torch/hub/facebookresearch_dinov2_main/dinov2/layers/attention.py:33: UserWarning: xFormers is not available (Attention)
#   warnings.warn("xFormers is not available (Attention)")
# /root/.cache/torch/hub/facebookresearch_dinov2_main/dinov2/layers/block.py:40: UserWarning: xFormers is not available (Block)
#   warnings.warn("xFormers is not available (Block)")
# Downloading: "https://dl.fbaipublicfiles.com/dinov2/dinov2_vitb14/dinov2_vitb14_reg4_pretrain.pth" to /root/.cache/torch/hub/checkpoints/dinov2_vitb14_reg4_pretrain.pth
# 100%|██████████| 330M/330M [00:01<00:00, 223MB/s]
# DinoVisionTransformer(
#   (patch_embed): PatchEmbed(
#     (proj): Conv2d(3, 768, kernel_size=(14, 14), stride=(14, 14))
#     (norm): Identity()
#   )
#   (blocks): ModuleList(
#     (0-11): 12 x NestedTensorBlock(
#       (norm1): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#       (attn): MemEffAttention(
#         (qkv): Linear(in_features=768, out_features=2304, bias=True)
#         (proj): Linear(in_features=768, out_features=768, bias=True)
#         (proj_drop): Dropout(p=0.0, inplace=False)
#       )
#       (ls1): LayerScale()
#       (drop_path1): Identity()
#       (norm2): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#       (mlp): Mlp(
#         (fc1): Linear(in_features=768, out_features=3072, bias=True)
#         (act): GELU(approximate='none')
#         (fc2): Linear(in_features=3072, out_features=768, bias=True)
#         (drop): Dropout(p=0.0, inplace=False)
#       )
#       (ls2): LayerScale()
#       (drop_path2): Identity()
#     )
#   )
#   (norm): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#   (head): Identity()
# )

# %%
print(dir(backbone))
# Out:
# ['T_destination', '__annotations__', '__call__', '__class__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattr__', '__getattribute__', '__getstate__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__setstate__', '__sizeof__', '__str__', '__subclasshook__', '__weakref__', '_apply', '_backward_hooks', '_backward_pre_hooks', '_buffers', '_call_impl', '_compiled_call_impl', '_forward_hooks', '_forward_hooks_always_called', '_forward_hooks_with_kwargs', '_forward_pre_hooks', '_forward_pre_hooks_with_kwargs', '_get_backward_hooks', '_get_backward_pre_hooks', '_get_intermediate_layers_chunked', '_get_intermediate_layers_not_chunked', '_get_name', '_is_full_backward_hook', '_load_from_state_dict', '_load_state_dict_post_hooks', '_load_state_dict_pre_hooks', '_maybe_warn_non_full_backward_hook', '_modules', '_named_members', '_non_persistent_buffers_set', '_parameters', '_register_load_state_dict_pre_hook', '_register_state_dict_hook', '_replicate_for_data_parallel', '_save_to_state_dict', '_slow_forward', '_state_dict_hooks', '_state_dict_pre_hooks', '_version', '_wrapped_call_impl', 'add_module', 'apply', 'bag_of_channels', 'bfloat16', 'blocks', 'buffers', 'call_super_init', 'children', 'chunked_blocks', 'cls_token', 'compile', 'cpu', 'cuda', 'double', 'dump_patches', 'embed_dim', 'eval', 'extra_repr', 'float', 'forward', 'forward_features', 'forward_features_list', 'get_buffer', 'get_extra_state', 'get_intermediate_layers', 'get_parameter', 'get_submodule', 'half', 'head', 'init_weights', 'interpolate_antialias', 'interpolate_offset', 'interpolate_pos_encoding', 'ipu', 'load_state_dict', 'mask_token', 'modules', 'mtia', 'n_blocks', 'named_buffers', 'named_children', 'named_modules', 'named_parameters', 'norm', 'num_features', 'num_heads', 'num_register_tokens', 'num_tokens', 'parameters', 'patch_embed', 'patch_size', 'pos_embed', 'prepare_tokens_with_masks', 'register_backward_hook', 'register_buffer', 'register_forward_hook', 'register_forward_pre_hook', 'register_full_backward_hook', 'register_full_backward_pre_hook', 'register_load_state_dict_post_hook', 'register_load_state_dict_pre_hook', 'register_module', 'register_parameter', 'register_state_dict_post_hook', 'register_state_dict_pre_hook', 'register_tokens', 'requires_grad_', 'set_extra_state', 'set_submodule', 'share_memory', 'state_dict', 'to', 'to_empty', 'train', 'training', 'type', 'xpu', 'zero_grad']

# %%
for name, param in backbone.named_parameters():
    print(f"Name : {name} | Size : {param.shape}")
# Out:
# Name : cls_token | Size : torch.Size([1, 1, 768])
# Name : pos_embed | Size : torch.Size([1, 1370, 768])
# Name : register_tokens | Size : torch.Size([1, 4, 768])
# Name : mask_token | Size : torch.Size([1, 768])
# Name : patch_embed.proj.weight | Size : torch.Size([768, 3, 14, 14])
# Name : patch_embed.proj.bias | Size : torch.Size([768])
# Name : blocks.0.norm1.weight | Size : torch.Size([768])
# Name : blocks.0.norm1.bias | Size : torch.Size([768])
# Name : blocks.0.attn.qkv.weight | Size : torch.Size([2304, 768])
# Name : blocks.0.attn.qkv.bias | Size : torch.Size([2304])
# Name : blocks.0.attn.proj.weight | Size : torch.Size([768, 768])
# Name : blocks.0.attn.proj.bias | Size : torch.Size([768])
# Name : blocks.0.ls1.gamma | Size : torch.Size([768])
# Name : blocks.0.norm2.weight | Size : torch.Size([768])
# Name : blocks.0.norm2.bias | Size : torch.Size([768])
# Name : blocks.0.mlp.fc1.weight | Size : torch.Size([3072, 768])
# Name : blocks.0.mlp.fc1.bias | Size : torch.Size([3072])
# Name : blocks.0.mlp.fc2.weight | Size : torch.Size([768, 3072])
# Name : blocks.0.mlp.fc2.bias | Size : torch.Size([768])
# Name : blocks.0.ls2.gamma | Size : torch.Size([768])
# Name : blocks.1.norm1.weight | Size : torch.Size([768])
# Name : blocks.1.norm1.bias | Size : torch.Size([768])
# Name : blocks.1.attn.qkv.weight | Size : torch.Size([2304, 768])
# Name : blocks.1.attn.qkv.bias | Size : torch.Size([2304])
# Name : blocks.1.attn.proj.weight | Size : torch.Size([768, 768])
# Name : blocks.1.attn.proj.bias | Size : torch.Size([768])
# Name : blocks.1.ls1.gamma | Size : torch.Size([768])
# Name : blocks.1.norm2.weight | Size : torch.Size([768])
# Name : blocks.1.norm2.bias | Size : torch.Size([768])
# Name : blocks.1.mlp.fc1.weight | Size : torch.Size([3072, 768])
# Name : blocks.1.mlp.fc1.bias | Size : torch.Size([3072])
# Name : blocks.1.mlp.fc2.weight | Size : torch.Size([768, 3072])
# Name : blocks.1.mlp.fc2.bias | Size : torch.Size([768])
# Name : blocks.1.ls2.gamma | Size : torch.Size([768])
# Name : blocks.2.norm1.weight | Size : torch.Size([768])
# Name : blocks.2.norm1.bias | Size : torch.Size([768])
# Name : blocks.2.attn.qkv.weight | Size : torch.Size([2304, 768])
# Name : blocks.2.attn.qkv.bias | Size : torch.Size([2304])
# Name : blocks.2.attn.proj.weight | Size : torch.Size([768, 768])
# Name : blocks.2.attn.proj.bias | Size : torch.Size([768])
# Name : blocks.2.ls1.gamma | Size : torch.Size([768])
# Name : blocks.2.norm2.weight | Size : torch.Size([768])
# Name : blocks.2.norm2.bias | Size : torch.Size([768])
# Name : blocks.2.mlp.fc1.weight | Size : torch.Size([3072, 768])
# Name : blocks.2.mlp.fc1.bias | Size : torch.Size([3072])
# Name : blocks.2.mlp.fc2.weight | Size : torch.Size([768, 3072])
# Name : blocks.2.mlp.fc2.bias | Size : torch.Size([768])
# Name : blocks.2.ls2.gamma | Size : torch.Size([768])
# Name : blocks.3.norm1.weight | Size : torch.Size([768])
# Name : blocks.3.norm1.bias | Size : torch.Size([768])
# Name : blocks.3.attn.qkv.weight | Size : torch.Size([2304, 768])
# Name : blocks.3.attn.qkv.bias | Size : torch.Size([2304])
# Name : blocks.3.attn.proj.weight | Size : torch.Size([768, 768])
# Name : blocks.3.attn.proj.bias | Size : torch.Size([768])
# Name : blocks.3.ls1.gamma | Size : torch.Size([768])
# Name : blocks.3.norm2.weight | Size : torch.Size([768])
# Name : blocks.3.norm2.bias | Size : torch.Size([768])
# Name : blocks.3.mlp.fc1.weight | Size : torch.Size([3072, 768])
# Name : blocks.3.mlp.fc1.bias | Size : torch.Size([3072])
# Name : blocks.3.mlp.fc2.weight | Size : torch.Size([768, 3072])
# Name : blocks.3.mlp.fc2.bias | Size : torch.Size([768])
# Name : blocks.3.ls2.gamma | Size : torch.Size([768])
# Name : blocks.4.norm1.weight | Size : torch.Size([768])
# Name : blocks.4.norm1.bias | Size : torch.Size([768])
# Name : blocks.4.attn.qkv.weight | Size : torch.Size([2304, 768])
# Name : blocks.4.attn.qkv.bias | Size : torch.Size([2304])
# Name : blocks.4.attn.proj.weight | Size : torch.Size([768, 768])
# Name : blocks.4.attn.proj.bias | Size : torch.Size([768])
# Name : blocks.4.ls1.gamma | Size : torch.Size([768])
# Name : blocks.4.norm2.weight | Size : torch.Size([768])
# Name : blocks.4.norm2.bias | Size : torch.Size([768])
# Name : blocks.4.mlp.fc1.weight | Size : torch.Size([3072, 768])
# Name : blocks.4.mlp.fc1.bias | Size : torch.Size([3072])
# Name : blocks.4.mlp.fc2.weight | Size : torch.Size([768, 3072])
# Name : blocks.4.mlp.fc2.bias | Size : torch.Size([768])
# Name : blocks.4.ls2.gamma | Size : torch.Size([768])
# Name : blocks.5.norm1.weight | Size : torch.Size([768])
# Name : blocks.5.norm1.bias | Size : torch.Size([768])
# Name : blocks.5.attn.qkv.weight | Size : torch.Size([2304, 768])
# Name : blocks.5.attn.qkv.bias | Size : torch.Size([2304])
# Name : blocks.5.attn.proj.weight | Size : torch.Size([768, 768])
# Name : blocks.5.attn.proj.bias | Size : torch.Size([768])
# Name : blocks.5.ls1.gamma | Size : torch.Size([768])
# Name : blocks.5.norm2.weight | Size : torch.Size([768])
# Name : blocks.5.norm2.bias | Size : torch.Size([768])
# Name : blocks.5.mlp.fc1.weight | Size : torch.Size([3072, 768])
# Name : blocks.5.mlp.fc1.bias | Size : torch.Size([3072])
# Name : blocks.5.mlp.fc2.weight | Size : torch.Size([768, 3072])
# Name : blocks.5.mlp.fc2.bias | Size : torch.Size([768])
# Name : blocks.5.ls2.gamma | Size : torch.Size([768])
# Name : blocks.6.norm1.weight | Size : torch.Size([768])
# Name : blocks.6.norm1.bias | Size : torch.Size([768])
# Name : blocks.6.attn.qkv.weight | Size : torch.Size([2304, 768])
# Name : blocks.6.attn.qkv.bias | Size : torch.Size([2304])
# Name : blocks.6.attn.proj.weight | Size : torch.Size([768, 768])
# Name : blocks.6.attn.proj.bias | Size : torch.Size([768])
# Name : blocks.6.ls1.gamma | Size : torch.Size([768])
# Name : blocks.6.norm2.weight | Size : torch.Size([768])
# Name : blocks.6.norm2.bias | Size : torch.Size([768])
# Name : blocks.6.mlp.fc1.weight | Size : torch.Size([3072, 768])
# Name : blocks.6.mlp.fc1.bias | Size : torch.Size([3072])
# Name : blocks.6.mlp.fc2.weight | Size : torch.Size([768, 3072])
# Name : blocks.6.mlp.fc2.bias | Size : torch.Size([768])
# Name : blocks.6.ls2.gamma | Size : torch.Size([768])
# Name : blocks.7.norm1.weight | Size : torch.Size([768])
# Name : blocks.7.norm1.bias | Size : torch.Size([768])
# Name : blocks.7.attn.qkv.weight | Size : torch.Size([2304, 768])
# Name : blocks.7.attn.qkv.bias | Size : torch.Size([2304])
# Name : blocks.7.attn.proj.weight | Size : torch.Size([768, 768])
# Name : blocks.7.attn.proj.bias | Size : torch.Size([768])
# Name : blocks.7.ls1.gamma | Size : torch.Size([768])
# Name : blocks.7.norm2.weight | Size : torch.Size([768])
# Name : blocks.7.norm2.bias | Size : torch.Size([768])
# Name : blocks.7.mlp.fc1.weight | Size : torch.Size([3072, 768])
# Name : blocks.7.mlp.fc1.bias | Size : torch.Size([3072])
# Name : blocks.7.mlp.fc2.weight | Size : torch.Size([768, 3072])
# Name : blocks.7.mlp.fc2.bias | Size : torch.Size([768])
# Name : blocks.7.ls2.gamma | Size : torch.Size([768])
# Name : blocks.8.norm1.weight | Size : torch.Size([768])
# Name : blocks.8.norm1.bias | Size : torch.Size([768])
# Name : blocks.8.attn.qkv.weight | Size : torch.Size([2304, 768])
# Name : blocks.8.attn.qkv.bias | Size : torch.Size([2304])
# Name : blocks.8.attn.proj.weight | Size : torch.Size([768, 768])
# Name : blocks.8.attn.proj.bias | Size : torch.Size([768])
# Name : blocks.8.ls1.gamma | Size : torch.Size([768])
# Name : blocks.8.norm2.weight | Size : torch.Size([768])
# Name : blocks.8.norm2.bias | Size : torch.Size([768])
# Name : blocks.8.mlp.fc1.weight | Size : torch.Size([3072, 768])
# Name : blocks.8.mlp.fc1.bias | Size : torch.Size([3072])
# Name : blocks.8.mlp.fc2.weight | Size : torch.Size([768, 3072])
# Name : blocks.8.mlp.fc2.bias | Size : torch.Size([768])
# Name : blocks.8.ls2.gamma | Size : torch.Size([768])
# Name : blocks.9.norm1.weight | Size : torch.Size([768])
# Name : blocks.9.norm1.bias | Size : torch.Size([768])
# Name : blocks.9.attn.qkv.weight | Size : torch.Size([2304, 768])
# Name : blocks.9.attn.qkv.bias | Size : torch.Size([2304])
# Name : blocks.9.attn.proj.weight | Size : torch.Size([768, 768])
# Name : blocks.9.attn.proj.bias | Size : torch.Size([768])
# Name : blocks.9.ls1.gamma | Size : torch.Size([768])
# Name : blocks.9.norm2.weight | Size : torch.Size([768])
# Name : blocks.9.norm2.bias | Size : torch.Size([768])
# Name : blocks.9.mlp.fc1.weight | Size : torch.Size([3072, 768])
# Name : blocks.9.mlp.fc1.bias | Size : torch.Size([3072])
# Name : blocks.9.mlp.fc2.weight | Size : torch.Size([768, 3072])
# Name : blocks.9.mlp.fc2.bias | Size : torch.Size([768])
# Name : blocks.9.ls2.gamma | Size : torch.Size([768])
# Name : blocks.10.norm1.weight | Size : torch.Size([768])
# Name : blocks.10.norm1.bias | Size : torch.Size([768])
# Name : blocks.10.attn.qkv.weight | Size : torch.Size([2304, 768])
# Name : blocks.10.attn.qkv.bias | Size : torch.Size([2304])
# Name : blocks.10.attn.proj.weight | Size : torch.Size([768, 768])
# Name : blocks.10.attn.proj.bias | Size : torch.Size([768])
# Name : blocks.10.ls1.gamma | Size : torch.Size([768])
# Name : blocks.10.norm2.weight | Size : torch.Size([768])
# Name : blocks.10.norm2.bias | Size : torch.Size([768])
# Name : blocks.10.mlp.fc1.weight | Size : torch.Size([3072, 768])
# Name : blocks.10.mlp.fc1.bias | Size : torch.Size([3072])
# Name : blocks.10.mlp.fc2.weight | Size : torch.Size([768, 3072])
# Name : blocks.10.mlp.fc2.bias | Size : torch.Size([768])
# Name : blocks.10.ls2.gamma | Size : torch.Size([768])
# Name : blocks.11.norm1.weight | Size : torch.Size([768])
# Name : blocks.11.norm1.bias | Size : torch.Size([768])
# Name : blocks.11.attn.qkv.weight | Size : torch.Size([2304, 768])
# Name : blocks.11.attn.qkv.bias | Size : torch.Size([2304])
# Name : blocks.11.attn.proj.weight | Size : torch.Size([768, 768])
# Name : blocks.11.attn.proj.bias | Size : torch.Size([768])
# Name : blocks.11.ls1.gamma | Size : torch.Size([768])
# Name : blocks.11.norm2.weight | Size : torch.Size([768])
# Name : blocks.11.norm2.bias | Size : torch.Size([768])
# Name : blocks.11.mlp.fc1.weight | Size : torch.Size([3072, 768])
# Name : blocks.11.mlp.fc1.bias | Size : torch.Size([3072])
# Name : blocks.11.mlp.fc2.weight | Size : torch.Size([768, 3072])
# Name : blocks.11.mlp.fc2.bias | Size : torch.Size([768])
# Name : blocks.11.ls2.gamma | Size : torch.Size([768])
# Name : norm.weight | Size : torch.Size([768])
# Name : norm.bias | Size : torch.Size([768])
